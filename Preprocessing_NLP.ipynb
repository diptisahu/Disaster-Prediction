# %% [markdown]
# ## 1. Data Acquisition
#
# This project utilizes the Disaster Identification Tweet dataset which consists of the following:
#
#
# 1.  train.csv
# 2.  test.csv
# 3.  sample_submission.csv
#
# As part of this step, we read the training and testing data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/NLP-Project
# Out:
# /content/drive/MyDrive/NLP-Project

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
train_dataset = pd.read_csv("clean_train.csv")
print("Training Dataset Features:")
print(train_dataset.keys())
print("Unique Values in id =", train_dataset['id'].nunique())
print("Unique Values in keyword =", train_dataset['keyword'].nunique())
print("Unique Values in location =", train_dataset['location'].nunique())
print("Unique Values in text =", train_dataset['text'].nunique())
print("Unique Values in target =", train_dataset['target'].nunique())
# Out:
# Training Dataset Features:
# Index(['id', 'keyword', 'location', 'text', 'target'], dtype='object')
# Unique Values in id = 7613
# Unique Values in keyword = 221
# Unique Values in location = 3291
# Unique Values in text = 6949
# Unique Values in target = 2

# %% [markdown]
# ## 3. Pre-processing
#
# The pre-processing step involves the following:
#
#
# 1.   Remove hyperlink
# 2.   Tokenize
# 3.   Stop word removal
# 4.   Removing numbers
# 5.   Removing special characters
# 6.   Conversion to Lower Case
# 7.   Remove Empty Spaces

# %%
def removehyperlink(text):
  temptext = []
  for i in text:
    temp = i.split()
    temp = [j.lower() for j in temp if not j.startswith('http://')]
    temp = [j for j in temp if not j.startswith('https://')]
    temptext.append(temp)
  return temptext

# %%
def TokenizeText(text):
  temptext = []
  for i in text:
    temptext.append(i.split())
  return temptext

# %%
def removespecialcharacter(text):
  temptext = []
  for i in text:
    temp = []
    for j in i:
      temp.append(re.sub(r"[^a-zA-Z0-9]","",j))
    temptext.append(temp)
  return temptext

# %%
def removeemptyspace(text):
  temptext = []
  for i in text:
    temp = []
    for j in i:
      if j != '':
        temp.append(j)
    temptext.append(temp)
  return temptext

# %%
def removenumbers(text):
  temptext = []
  for i in text:
    temp = []
    for j in i:
      if j != '':
        temp.append(re.sub(r'[~^0-9]', '',j))
    temptext.append(temp)
  return temptext

# %%
def lowercase(text):
  temptext = []
  for i in text:
    temp = []
    for j in i:
      temp.append(j.lower())
    temptext.append(temp)
  return temptext

# %%
def removestopwords(text):
  temptext = []
  stop_words = set(stopwords.words('english'))
  for i in text:
    temp = []
    for j in i:
      if j not in stop_words:
        temp.append(j)
    temptext.append(temp)
  return temptext

# %%
clean = TokenizeText(train_dataset['text'])
clean = removespecialcharacter(clean)
clean = removeemptyspace(clean)
clean = removenumbers(clean)
clean = removeemptyspace(clean)
clean = lowercase(clean)
clean = removestopwords(clean)

# %%
vocab_sentence = []
for i in clean:
  temp = " ".join([j for j in i])
  vocab_sentence.append(temp)

print(vocab_sentence)
# Out:
# ['deeds reason earthquake may allah forgive us', 'forest fire near la ronge sask canada', 'residents asked shelter place notified officers evacuation shelter place orders expected', 'people receive wildfires evacuation orders california', 'got sent photo ruby alaska smoke wildfires pours school', 'rockyfire update california hwy closed directions due lake county fire cafire wildfires', 'flood disaster heavy rain causes flash flooding streets manitou colorado springs areas', 'top hill see fire woods', 'emergency evacuation happening building across street', 'afraid tornado coming area', 'three people died heat wave far', 'haha south tampa getting flooded hah wait second live south tampa gonna gonna fvck flooding', 'raining flooding florida tampabay tampa days lost count', 'flood bago myanmar arrived bago', 'damage school bus multi car crash breaking', 'man', 'love fruits', 'summer lovely', 'car fast', 'goooooooaaaaaal', 'ridiculous', 'london cool', 'love skiing', 'wonderful day', 'looooool', 'way cannot eat shit', 'nyc last week', 'love girlfriend', 'cooool', 'like pasta', 'end', 'bbcmtd wholesale markets ablaze', 'always try bring heavy metal rt', 'africanbaze breaking news nigeria flag set ablaze aba', 'crying set ablaze', 'plus side look sky last night ablaze', 'phdsquares mufc built much hype around new acquisitions doubt set epl ablaze season', 'inec office abia set ablaze', 'barbados bridgetown jamaica two cars set ablaze santa cruz head st elizabeth police superintende', 'ablaze lord', 'check nsfw', 'outside ablaze alive dead inside', 'awesome time visiting cfc head office ancop site ablaze thanks tita vida taking care us', 'soooo pumped ablaze southridgelife', 'wanted set chicago ablaze preaching hotel', 'gained followers last week know stats grow', 'west burned thousands wildfires ablaze california alone', 'building perfect tracklist life leave streets ablaze', 'check nsfw', 'first night retainers quite weird better get used wear every single night next year least', 'deputies man shot brighton home set ablaze', 'man wife get six years jail setting ablaze niece', 'santa cruz head st elizabeth police superintendent lanford salmon r', 'police arsonist deliberately set black church north carolinaablaze', 'noches el bestia alexissanchez happy see teammates training hard goodnight gunners', 'kurds trampling turkmen flag later set ablaze others vandalized offices turkmen front diyala', 'truck ablaze r voortrekker ave outside tambo intl cargo section', 'set hearts ablaze every city gift every skyline like kiss upon lips', 'sky ablaze tonight los angeles expecting ig fb filled sunset shots know peeps', 'west burned thousands wildfires ablaze california alone climate energy', 'revel wmv videos means mac farewell ablaze wmv en route dvd gtxrwm', 'progressive greetings month students would set pens ablaze torch publications', 'rene ablaze jacinta secret k fallen skies edit mar', 'navista steve fires something else california tinderbox clown setting hood ablaze news', 'nowplaying rene ablaze ian buff magnitude edm', 'nxwestmidlands huge fire wholesale markets ablaze', 'ablaze time talk go know make due work', 'cannot kids cuz got bicycle accident split testicles impossible kids michael father', 'accident w nashvilletraffic traffic moving slower usual', 'accident center lane blocked santaclara us nb great america pkwy bayarea traffic', 'personalinjury accident summer read advice see solicitor help otleyhour', 'stlouis caraccidentlawyer speeding among top causes teen accidents car accident tee', 'reported motor vehicle accident curry herman rd near stephenson involving overturned vehicle please use', 'bigrigradio live accident awareness', 'mile marker south mooresville iredell vehicle accident ramp closed pm', 'rt sleepjunkies sleeping pills double risk car accident', 'accident knew gon happen', 'traffic accident n cabrillo hwy magellan av mir', 'mile marker south mooresville iredell vehicle accident congestion pm', 'pastor scene acc ...
